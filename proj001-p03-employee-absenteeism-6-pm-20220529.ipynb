# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/DWQOJgU.png" width="1500">
#
#  <h1 style="text-alignment:justify">Employee Absenteeism during Work Time- Part 1</h1>
# <hr>
# 29 May 2022

# %% [markdown]
# <div>
# <img style="float: left" src="https://i.postimg.cc/qvZpHzhk/002-Img-Objectives-Draft-2-20220819.png(https://postimg.cc/cvYpQ1Bj)" width="75">
# <h2 id="Obj1">Objectives</h2>
# <hr>
#
# <h3 style="text-align:justify">In this project,with the high competitiveness of company today has led to an increased in pressure in the work place. The company expectation becoming high thus there is the probability that the target can not be attained and might raise stress level. The low performance will increase the possibility of the employee being laid off. These can lead to the deteriorate of health gradually or even suddenly.
# <br><br>
# by predicting employees absenteeism, it might be possible to identify factors that contribute. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.</h3>
# <p style = "font-family: Arial; font-size: 18px">Note: This project's dataset was created for pedagogical purposes and may not be indicative of the data.</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Remember:</b><p style = "font-family:Verdana; font-size:14px">We must be <b>objective</b> in analyzing the data in order to acquire valuable insights and understand it by collecting, fact checking or challenging the data and other sources. Go to where the data - Genchi Genbutsu attitudes. Data must be <b>Clear, Objective, Valuable, Focus, Agile, Scientific and Timeframe (COV-FAST)</b></p>
#     <p style = "font-family:Verdana; font-size:14px">There are methodologies to be considered logistic regression, random forest or neural networking. We can use the same preprocessing dataset and try each options methodologies in seperate notebooks</p>
# </div>
#     <h3>Methodologies Overview</h3>
# <h3>Data Analysis PACE Steps:</h3>
#    <ol style="font-family:Verdana; font-size:16px">
#     <li><img style="float:left" src="https://i.imgur.com/gIne5bH.png" width="50"> Define (Plan & Analyze - EDA) - PART 1</li>
#     <blockquote>
#     <ol>Understand your data in the problem context
#         <br>EDA - check model, assumption & select model
#     </ol>
#     </blockquote>
#         <li><img style="float:left" src="https://i.imgur.com/rb8V6X5.png" width="50">Measure (Analyze - EDA)</li>
#     <blockquote>
#     <ol> EDA - check model, assumption & select model
#      </ol>
#     </blockquote>
#     <li><img style="float:left" src="https://i.imgur.com/J4M3HKM.png" width="50">Analyze (Construct) </li>
#     <blockquote>
#     <ol>Contruct and evaluate model
#      </ol>
#     </blockquote>
#     <li><img style="float:left" src="https://i.imgur.com/wpcEXQC.png" width="50">Improve (Execute) - interpret model and share the story</li>
#     <br>
#     <li>Control</li>

# %% [markdown]
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="50">
# <div class="alert alert-block alert-info">
# <b style = "font-family: Arial; font-size: 16px">Advices:</b>
#     <ol style = "text-align:justify; font-family: Verdana; font-size: 14px">
#         <li> Please <b>take your time to Read, Understand,</b> <b><em>PRACTICE, PRACTICE, PRACTICE,</em></b> and <b>Solve the problems Independently</b> before asking <b>Question</b>. <em>Become a detective and solve cases.</em> These will help you build self-reliance and grow to challenges. <b>Keep Curious, Passionate and Healthy</b>.</li>
#         <li> <b>Beginner or Newbie</b> should start learning by <b>focusing</b> only 1(one) notebook. This article uses <b>Kaggle</b> and you will have already registered or been able to log in in the notebook. A similar article is available in my GitHub</li>
#          <li> Certain problem solving challenges might be available in the end of the notebook and questions are welcomed. </li>
#          <li> <b>Keep your spirit! Semangat! Ganbatei!-がんばって, Jiā yóu!-加油 Espíritu!, Hwaiting!-화이팅, Aatma!-आत्मा, Dukh!-дух, Esprit, Hamasa!-حَمَاسَة</b>. </li>
#         <li> Please note that the software's version may have changed or upgraded after the article was created. </li>
#     </ol>
#
# <b>Thank you! Terima kasih! Arigatōgozaimashita!-ありがとうございました, Xièxiè nǐ!-谢谢你, Gracias!, Gamsahabnida!-감사합니다, Dhanyavaad!-धन्यवाद, Spasibo!-cпасибо, Merci, shkran lak!-شكرًا لك
#     </b>
# </div>

# %% [markdown]
# # Methodologies Overview
# <hr>
#
# <h3 style = "text-align:center">Table 1.1. DMAIC vs Data Analytics Methodologies (Define)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">Six Sigma DMAIC 12 Steps</th>
#   </tr>
#
#   <tr>
#         <th colspan="2"><em>Define</em></th>
#     <th colspan="3">Customer expectations of the process? </th>
#   </tr>
#
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >A
#       </td>
#     <td>Identify Project's CTQ</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       CTQ drill down tree,
#         VOC, Pareto, Bar Chart
#     </td>
#       <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >B
#       </td>
#     <td>Define Process Mapping</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      SIPOC
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >C
#       </td>
#     <td>Establish The Team's Charter</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Milestones, Team Members, Stakeholders, Project Charter
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps - Project Initiation and Planning Phase</th>
#   </tr>
#
#  <tr>
#         <th colspan="2"><em>Ask and Prepare</em></th>
#     <th colspan="3">Customer expectations of the process? </th>
#  </tr>
#
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >Ask - Mining
#       </td>
#     <td>A Clear Statement of The Business Task</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       CTQ drill down tree,
#         VOC, Pareto, Bar Chart
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >Ask - Mining
#       </td>
#     <td>Mapping Key Stakholders</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      RACI Matrix
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >Prepare
#       </td>
#     <td>A Description of All Data Used</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Data Preparation or Mining
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#
#  </table>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.2. DMAIC vs Data Analytics Methodologies (Measure)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">Six Sigma DMAIC 12 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Measure</em></th>
#     <th colspan="3">What is the frequency of defects?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >1
#       </td>
#     <td>CTQ's Selection</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#      Bar Chart, FMEA
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >2
#       </td>
#     <td>Establish Performance Standard</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#     Management Decision Process
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >3
#       </td>
#     <td>Measurement System Analysis</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Gage R&R
#     </td>
#     <td style ="text-align:center">
#       14 - 21 days
#     </td>
#   </tr>
#
#   <tr>
#     <td style ="text-align:left" >4
#       </td>
#     <td>Measure Current Capabilities</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Capability Indices, Current Sigma
#     </td>
#     <td style ="text-align:center">
#       2 weeks - 1 month
#     </td>
#   </tr>
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps - Project Initiation and Planning Phase</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Prepare, Process and Analyze</em></th>
#     <th colspan="3">What is the frequency of defects?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Prepare
#       </td>
#     <td>A Description of Data
#         for Measurement
#         (Critical Data Used)</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       Bar Chart, FMEA
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Prepare
#       </td>
#     <td> A Description of  Baseline
#         Standard Performance Data</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Management Decision Process
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Process
#       </td>
#     <td>Documentation of any Cleaning or Manipulation of Data</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Gage R&R
#     </td>
#     <td style ="text-align:center">
#       14 - 21 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Analyze
#       </td>
#     <td>A Summary of the Baseline Analysis</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Capability Indices, Current Sigma
#     </td>
#     <td style ="text-align:center">
#       2 weeks - 1 month
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.3. DMAIC vs Data Analytics Methodologies (Analyze)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">Six Sigma DMAIC 12 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Analyze</em></th>
#     <th colspan="3">Why, when and where defects occur?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >5
#       </td>
#     <td>Establish Performance Objectives</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#      Team, Benchmarking
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >6
#       </td>
#     <td>Identify the Variances Source</td>
#     <td style = "text-align:center">
#      X
#     </td>
#     <td style ="text-align:left">
#     Fishbone, Time Value Map, Hyphothesis Test
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Share and Act</em></th>
#     <th colspan="3">What is the frequency of defects?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Share
#       </td>
#     <td>Support Visualization and Key Findings</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       Team, Benchmarking
#     </td>
#     <td style ="text-align:center">
#       3 - 5 days
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Act
#       </td>
#     <td>Top Three Recommendations Based on Analysis</td>
#     <td style = "text-align:center">
#      X
#     </td>
#     <td style ="text-align:left">
#      Fishbone, Hyphothesis Test
#     </td>
#     <td style ="text-align:center">
#       2 weeks - 1 month
#     </td>
#   </tr>
#  </table>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.4. DMAIC vs Data Analytics Methodologies (Improve)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">Six Sigma DMAIC 12 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Improve</em></th>
#     <th colspan="3">How can we improve the process?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >7
#       </td>
#     <td>Determine the Potential Causes</td>
#     <td style = "text-align:center">
#       X
#     </td>
#     <td style ="text-align:left">
#      Brainstroming, DOE
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >8
#       </td>
#     <td>Identify the Varibles Relation</td>
#     <td style = "text-align:center">
#      X
#     </td>
#     <td style ="text-align:left">
#     Factorial Design, Main
#     Effect Interaction Plot
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >9
#       </td>
#     <td>Define the Process Map</td>
#     <td style = "text-align:center">
#      Y,X
#     </td>
#     <td style ="text-align:left">
#     Simulasi, 5W-2H
#     </td>
#     <td style ="text-align:center">
#       14 Days - 21 Days
#     </td>
#   </tr>
#
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Analyze, Share and Act</em></th>
#     <th colspan="3">How can we improve the process?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Process and Analyze
#       </td>
#     <td>Cleaning or Manipulation of Data.
#         A Summary of Your
#         Potential Causes Analysis</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       Brainstroming, DOE
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Share
#       </td>
#     <td>Support Visualization and
#         Key Findings of the Relationship</td>
#     <td style = "text-align:center">
#       Y
#     </td>
#     <td style ="text-align:left">
#       Factorial Design, Main
#     Effect Interaction Plot
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Act
#       </td>
#     <td>Improved Process Recommendations</td>
#     <td style = "text-align:center">
#      Y
#     </td>
#     <td style ="text-align:left">
#      Simulasi, 5W-2H
#     </td>
#     <td style ="text-align:center">
#       14 Days - 21 Days
#     </td>
#   </tr>
# </table>

# %% [markdown]
# <h3 style = "text-align:center">Table 1.5. DMAIC vs Data Analytics Methodologies (Control)</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <tr>
#     <th colspan="5">Six Sigma DMAIC 12 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Control</em></th>
#     <th colspan="3">How can we make the process stay fixed?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >10
#       </td>
#     <td>Validate The Actual Implementation
#         of The Measurement System</td>
#     <td style = "text-align:center">
#       Y,X
#     </td>
#     <td style ="text-align:left">
#      Gage R&R
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >11
#       </td>
#     <td>Determine The Capability Process</td>
#     <td style = "text-align:center">
#      Y,X
#     </td>
#     <td style ="text-align:left">
#     Capability Indices
#         Sigma Achievement
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >12
#       </td>
#     <td>Implement Process Control</td>
#     <td style = "text-align:center">
#      X
#     </td>
#     <td style ="text-align:left">
#     Tracking Every Time, FMEA
#     </td>
#     <td style ="text-align:center">
#       14 Days - 21 Days
#     </td>
#   </tr>
#
# <tr style = "border-top: solid ">
#     <th colspan="5">Data Analytics 6 Steps</th>
#   </tr>
#     <tr>
#         <th colspan="2"><em>Analyze, Share and Act</em></th>
#     <th colspan="3">How can we make the process stay fixed?</th>
#   </tr>
#   <tr>
#     <th>Steps</th>
#     <th>Description</th>
#     <th>Focus</th>
#     <th>Tools</th>
#     <th>Timeline</th>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Process and Analyze
#       </td>
#     <td>Cleaning or Manipulation
#         of Data and to Validate
#         Measurement System </td>
#     <td style = "text-align:center">
#       Y,X
#     </td>
#     <td style ="text-align:left">
#       Gage R&R
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Share
#       </td>
#     <td>Support Visualization and Key Findings
#         of the New Capabilities</td>
#     <td style = "text-align:center">
#       Y,X
#     </td>
#     <td style ="text-align:left">
#       Capability Indices
#         Sigma Achievement
#     </td>
#     <td style ="text-align:center">
#       2 Weeks - 1 Month
#     </td>
#   </tr>
#   <tr>
#     <td style ="text-align:left" >Act
#       </td>
#     <td>Recommendations to Track and Control</td>
#     <td style = "text-align:center">
#      X
#     </td>
#     <td style ="text-align:left">
#      Tracking Every Time, FMEA
#     </td>
#     <td style ="text-align:center">
#       14 Days - 21 Days
#     </td>
#   </tr>
# </table>

# %% [markdown]
# # 1. Define vs Ask and Prepare (Data Collection -  Preparation)
# ## A. Preparing Dataset

# %% [markdown]
# ### Load the Data

# %%
raw_csv_data = pd.read_csv('/kaggle/input/proj001-p01-employee-absenteeism/Absenteeism-data.csv')

# %%
raw_csv_data

# %%
df = raw_csv_data.copy()

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/gIne5bH.png" width="80">
#
# ## Import the relevant libraries

# %%
# For data visualization
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None #we can change the default number of rows to be displayed
pd.options.display.max_rows = 30 #Displays the default number of value. 

#Interpreter reads this value and displays the rows with this value as upper limit to display

# %%
display(df)

# %%
df.info()

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">As we can see above that the data has 700 data equally which there are no missing values. Dependant variable will be the y or the target which is Absenteeism Time in Hours </span>

# %%
df.describe()

# %% [markdown]
# #### Missing Values

# %%
df.isnull().sum()#True=1 = Missing Value and False = 0. It sum all the 1

# %%
sns.set(style='whitegrid')

# %%
sns.heatmap(df.isna(), yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">As we can see above from the data the ID has 36 IDs, from 700 data we have 36 employees and this data is taken from July 2015 to May 2018. There is no further details on the turnover. Hence, the limitation will be out of scope. There is ' Reason for Absence' columns, which has 0 to 26 reasons which are the causes or reasons the employees were not able to work. Not to mentioned that the 'daily work load average" is above minimum working hours. Moreover, the highest absenteeism hours reached to 120 hours. Here we determine the CTQs that we want to drilldown that contibutes to the target (y) of Absenteeism.</span>
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">There is several candidates to be noticed and as an analyst we can decide based on our data analysis and collaborate with the team that handle on daily basis. Reason of absence is the categorical number for the disease causes hence it is first layer. In addtion, the causes may be elaborated further and whether it can be controlled to achieve the target.</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">If we assume a work week of 40 hours and two weeks of vacation per year, then the average number of working hours per month of employees working Monday&ndash;Friday `= 50 weeks * 40 hours per week / 12 months = 166.67 hours per month`.
#     </p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px">The goal context should be realistic and based on the data as opposed as just to please your employer or others. Remember the <b>Clear, Objective, Focus, Valuable Agile, Scientific and Timeframe (COV-FAST)</b> principles. The variables is the data frame and the features is the data per column.</p>
# </div>

# %% [markdown]
# ### Simple example using Pareto
#
# ### Import the relevant libraries

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.ticker import PercentFormatter
import statsmodels.api as sm
import seaborn as sns
sns.set()

from sklearn.cluster import KMeans

# %%
cols = ['Reason for Absence','Absenteeism Time in Hours']
df_id_absent = df[cols]
df_id_absent.columns

# %%
# import pandas
import pandas as pd

# renaming the column by index
df_id_absent.columns.values[0:2] =["Reasons", "Absenteeism_Time" ]

print("\nAfter modifying first column:\n", df_id_absent)

# %%
df_id_absent = df_id_absent.groupby('Reasons').sum()
df_pareto = df_id_absent.sort_values(by=['Absenteeism_Time'], ascending=False)
df_pareto

# %%
pareto = 100 *df_pareto.Absenteeism_Time.cumsum() / df_pareto.Absenteeism_Time.sum()
df_pareto['Percentage']= pareto
df_pareto

# %%
# creating axes object and defining plot
ax = df_pareto.plot(kind = 'bar',use_index=True,
                    y = 'Absenteeism_Time', color = 'Blue',
                    linewidth = 3)

ax2 = df_pareto.plot(kind = 'line', use_index=False,
                y = 'Percentage', secondary_y = True,
                color = 'Orange', linewidth = 3, marker='D',
                ax = ax)

#title of the plot
plt.title("Pareto")

#labeling x and y-axis
ax.set_xlabel('Reasons', color = 'g')
ax.set_ylabel('Absenteeism_Time', color = "b")
ax2.set_ylabel('Percentage', color = 'r')

#defining display layout
plt.tight_layout()
#fig, axes = plt.subplots()
ax.legend(loc='center right', frameon=False)

ax2.hlines(y=80, xmin=0, xmax=10, linewidth=2, color='r',ls='--')
ax.vlines(x=10, ymin=0, ymax=590, linewidth=2, color='r',ls='--')

plt.savefig('pareto-reasons-absenteeism.png')

#show plot
plt.show()

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">Using Pareto, we can <b> focus </b> on 11 reasons from the highest precentage in order, ID 1,10,11,12,13,18, 19, 22,23,26, and 28.</span>

# %% [markdown]
# ### Reason for Absence
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">We have to ensure that the 'Age' column has the age filled. Using excel we usually use Pivot Table to ensure that the variable is clear from missing values</span>

# %%
pd.unique(df['Reason for Absence'])

# %%
df['Reason for Absence'].unique()

# %%
len(df['Reason for Absence'].unique()) # if from 0 it is should be 29, so there is 1 number missing

# %%
sorted(df['Reason for Absence'].unique()) #we find 20 not available

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">'Reason for Absence' is a categorical number that corespondence with a disease and number 20 is not available. it can be as the reason that no one have ever caught the disease or there are number 0 which should be 20 as it should have started in number 1. Create dummy variables, 1 if the categorical effect is present and 0 if the same absent is absent.'get_dummies' convert categorical variable into dummy variable.</span>

# %% [markdown]
# ### 'get_dummies()'
#
#
# ### Reason for absence

# %%
reason_columns = pd.get_dummies(df['Reason for Absence'])

# %%
reason_columns

# %%
reason_columns['check'] = reason_columns.sum(axis=1) # all sum in the rows
reason_columns

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Create check column how many sum of reason(s) that was filled in each row.
#     </p>

# %%
reason_columns['check'].sum(axis=0) # total sum colom check 700

# %%
reason_columns['check'].unique() # all the variable in the column check is 1

# %%
reason_columns = reason_columns.drop(['check'], axis=1) # drop column check
reason_columns

# %% [markdown]
# ### 'get_dummies()'
#
#
# ### Age
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">We have to ensure that the 'Age' column has the age filled. Using excel we usually use Pivot Table to ensure that the variable is clear from missing values</span>

# %%
pd.unique(df['Age'])

# %%
len(df['Age'].unique()) #it is 21 because there shoul be people with the same age

# %%
sorted(df['Age'].unique())

# %% [markdown]
# ## Group the Reason for absence
#
# ### Drop Reason for absence 0 (zero)
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify"> As mentioned to avoid multicollinearity, 'Reason for Absence' for number 0 will be dropped. This step is to show the reason in the column and to simplify the reason with the same character put in 1 group.</span>

# %%
reason_columns = pd.get_dummies(df['Reason for Absence'], drop_first=True) # 0 is dropped

# %%
reason_columns

# %%
df.columns.values

# %%
reason_columns.columns.values

# %%
df = df.drop(['Reason for Absence'], axis=1) #reason for absence drop

# %%
df

# %%
reason_columns.loc[:, '1':'14'] #:, means all rows available, column 1 to 14 class 1, class 2 15 to 17, class 3 18 ro 21 and class 4 22 to 28

# %%
reason_columns.loc[:, '1':'14'].max(axis=1) #:, means all rows available, column 1 to 14 class 1, class 2 15 to 17, class 3 18 ro 21 and class 4 22 to 28

# %% [markdown]
# ### Group By 'Reasons for Absence'

# %%
reason_type_1 = reason_columns.loc[:, 1:14].max(axis=1)
reason_type_2 = reason_columns.loc[:, 15:17].max(axis=1)
reason_type_3 = reason_columns.loc[:, 18:21].max(axis=1)
reason_type_4 = reason_columns.loc[:, 22:].max(axis=1)

# %%
reason_type_2

# %% [markdown]
# ### Concate Column Values

# %%
df = pd.concat([df, reason_type_1, reason_type_2, reason_type_3, reason_type_4], axis = 1)
df # Reason for absence has changed

# %%
df.columns.values

# %%
column_names = ['ID', 'Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets', 'Absenteeism Time in Hours', 'reason_1', 'reason_2','reason_3', 'reason_4',]# Rename the column

# %%
df.columns = column_names

# %%
df.head()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">From 28 reasons have been put to 4 (general) clustered reasons.
#     </p>

# %% [markdown]
# ### Reorder Columns

# %%
column_names_reordered = ['reason_1', 'reason_2','reason_3', 'reason_4', 'Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets','ID', 'Absenteeism Time in Hours'] #Reorder the columns

# %%
df = df[column_names_reordered]

# %%
df.head()

# %% [markdown]
# ### Create a Checkpoint
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify"> Create a temporary save of your work to reduce risk of losing important data at a later stage (storing the current version of your code) .</span>

# %%
df_reason_mod = df.copy()

# %%
df_reason_mod

# %% [markdown]
# ## 'Date'

# %%
type(df_reason_mod['Date'][0]) #string - convert to timestamp values

# %%
#df_reason_mod['Date']=pd.to_datetime(df_reason_mod['Date'])

# %%
#df_reason_mod['Date']

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify"> We found inconsistency .</span>

# %%
df_reason_mod['Date']=pd.to_datetime(df_reason_mod['Date'], format = '%d/%m/%Y')

# %%
df_reason_mod['Date']

# %%
type(df_reason_mod['Date'][0])# Already to timestamp

# %%
df_reason_mod.info()

# %% [markdown]
# ### Extract the month value

# %%
df_reason_mod['Date'][0].month

# %%
list_months = []
list_months

# %%
df_reason_mod.shape

# %%
for i in range (df_reason_mod.shape[0]):
    list_months.append(df_reason_mod['Date'][i].month)

# %%
list_months

# %%
len(list_months)

# %%
df_reason_mod['Month Value'] = list_months

# %%
df_reason_mod.head(20)

# %% [markdown]
# ### Extract the day of the week

# %%
df_reason_mod['Date'][699].weekday()

# %%
df_reason_mod['Date'][699]

# %%
def date_to_weekday(date_value):
    return date_value.weekday()

# %%
df_reason_mod['Day of the week']= df_reason_mod['Date'].apply(date_to_weekday)

# %%
df_reason_mod.head()

# %% [markdown]
# ### Extract the day of the year

# %%
df_reason_mod['Date'][699].year

# %%
list_years = []
list_years

# %%
df_reason_mod.shape

# %%
for i in range (df_reason_mod.shape[0]):
    list_years.append(df_reason_mod['Date'][i].year)

# %%
list_years

# %%
len(list_years)

# %%
df_reason_mod['Year Value'] = list_years

# %%
df_reason_mod

# %% [markdown]
# ### Reorder the time in the front

# %%
df_reason_mod.columns.values

# %%
column_names_reordered = ['reason_1', 'reason_2','reason_3', 'reason_4', 'Month Value',
       'Day of the week', 'Year Value','Date', 'Transportation Expense', 'Distance to Work', 'Age',
       'Daily Work Load Average', 'Body Mass Index', 'Education',
       'Children', 'Pets','ID', 'Absenteeism Time in Hours']

# %%
df_reason_mod=df_reason_mod[column_names_reordered]

# %%
df_reason_mod.head(20)

# %% [markdown]
# ### Drop Date

# %%
df_reason_mod = df_reason_mod.drop(['Date'], axis=1)

# %%
df_reason_mod.head(20)

# %% [markdown]
# ### Create a Checkpoint
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify"> Create a temporary save of your work to reduce risk of losing important data at a later stage (storing the current version of your code) .</span>

# %%
df_reason_date_mod = df_reason_mod.copy()

# %%
df_reason_date_mod.head(20)

# %%
type(df_reason_date_mod['Transportation Expense'][0])

# %%
type(df_reason_date_mod['Distance to Work'][0])

# %%
type(df_reason_date_mod['Age'][0])

# %%
df_reason_date_mod.info()

# %%
df_reason_date_mod.describe()

# %%
df_reason_date_mod['Education'].unique()

# %%
df_reason_date_mod['Education'].value_counts()

# %%
df_reason_date_mod['Education'] = df_reason_date_mod['Education'].map({1:0, 2:1, 3:1, 4:1})#Education 2 to 4 is combine

# %%
df_reason_date_mod['Education'].unique()

# %%
df_reason_date_mod['Education'].value_counts()

# %% [markdown]
# ## Final Checkpoint

# %%
df_preprocessed = df_reason_date_mod.copy()
df_preprocessed.head()

# %%
df_preprocessed.to_csv('Absenteeism_preprocessed.csv', index=False)

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/rb8V6X5.png" width="50">
#
# ## Explarotary Data Analysis (EDA)

# %% [markdown]
# ### Create the Targets
#
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">Median as the cut off, where below and equal median will be moderately absent and above median is excessively absent. Moderately as 0 and the other class as 1.</span>

# %%
df_preprocessed['Absenteeism Time in Hours'].median()

# %%
targets = np.where(df_preprocessed['Absenteeism Time in Hours']>df_preprocessed['Absenteeism Time in Hours'].median(),1,0) #like if excel if > 3 then 1 else 0

# %%
targets

# %%
df_preprocessed['Excessive Absenteeism']=targets #Y

# %%
df_preprocessed.head()

# %% [markdown]
# ### A comment on the targets

# %%
targets.sum(), targets.shape[0]

# %%
targets.sum()/targets.shape[0]

# %%
ax = sns.countplot(x=df_preprocessed['Excessive Absenteeism'],
                   order=df_preprocessed['Excessive Absenteeism'].value_counts(ascending=False).index);
        
abs_values = df_preprocessed['Excessive Absenteeism'].value_counts(ascending=False)
rel_values = df_preprocessed['Excessive Absenteeism'].value_counts(ascending=False, normalize=True).values * 100
lbls = [f'{p[0]} ({p[1]:.0f}%)' for p in zip(abs_values, rel_values)]

ax.bar_label(container=ax.containers[0], labels=lbls)
plt.savefig('normal_vs_excessive.png',dpi=100, bbox_inches = "tight")

# %% [markdown]
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">Roughly 45% and 55% for Logistic Regression.</span>
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note back again:</b><p style = "font-family:Verdana; font-size:14px">After we have the value of the drop ratio go back to drop the features with no values and it shows that the result is the same as no impact getting rid of them.</p>
#     <p style = "font-family:Verdana; font-size:14px">We go columns_to_scale in standardizing and alter it to comment.Then, we create columns_to_omit instead</p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have 46% of Excessive Absenteeism or disengaged employee that we need to reduce to increase productivity.

# %% [markdown]
# #### Average excessive hours (disengaged employee) vs regular hours (engaged employee)

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism'])['Absenteeism Time in Hours'].agg([np.mean,np.median])

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism'])['Absenteeism Time in Hours'].agg([np.sum])

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">We have total 4030 hours from 2015 to 2018 of excessive absenteeism or disengaged employee and 703 hours from engaged employees. We still calculate based on more than 3 hours of absenteeism that we consider as disengaged employee and consider the unproductive hours.
#     </p>

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Year Value'])['Absenteeism Time in Hours'].agg([np.sum])

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['Absenteeism Time in Hours'].agg(['sum','count'])

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
ax = df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['Absenteeism Time in Hours'].agg([np.sum]).plot.bar()
ax1 = df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['Absenteeism Time in Hours'].agg([np.sum]).plot(legend=True)
ax.bar_label(container=ax.containers[0])
ax1.bar_label(container=ax.containers[0])
plt.savefig('normal_vs_excessive_absenteeism_hours.png',dpi=100, bbox_inches = "tight")

# %% [markdown]
# #### Number of Employee

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['ID'].nunique()

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['ID'].agg(['nunique'])

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
ax = df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['ID'].nunique().plot.bar()
ax1 = df_preprocessed.groupby(['Excessive Absenteeism','Year Value'])['ID'].nunique().plot(legend=True)
ax.bar_label(container=ax.containers[0])
ax1.bar_label(container=ax.containers[0])
plt.title('Normal vs Excessive Absenteeism Employee')
plt.savefig('normal_vs_excessive_employee.png',dpi=100, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">In 2015, we have total 31 employees, 17 disengaged employees and 14 engaged employees. 2016 and 2017 have a total of 47 employees and 2018 the company has 35 employees with 21 disengaged and 14 engaged.
#     </p>

# %% [markdown]
# #### Employee hours per week

# %%
# Calculate mean and median satisfaction scores of employees who left and those who stayed
df_preprocessed.groupby(['Excessive Absenteeism','Year Value', 'Month Value','Day of the week'])['Absenteeism Time in Hours'].agg(['sum','count'])

# %% [markdown]
# ### Drop 'ID'
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">We will only choose the data that has a mathematical logic to the target (y) for analysis. First we will drop ID.</span>

# %%
df_preprocessed.drop(['ID'], axis =1)# we have to specified the axis so not assumed rows here with number. Axis = zero (default). instead we type 1 tp show removing a column

# %%
df_preprocessed = df_preprocessed.drop(['ID'], axis =1) #permanently drop df
df_preprocessed

# %% [markdown]
# #### Overview of All Variables (X)

# %%
df_preprocessed = df_preprocessed.drop(['Absenteeism Time in Hours'], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">'Absenteeism Time in Hours' has been converted to 'Excessive Absenteeism.
#     </p>

# %%
plt.figure(figsize=(12,6))
sns.pairplot(df_preprocessed,hue="Excessive Absenteeism", palette="coolwarm")
plt.suptitle("Distribution by Excessive Absenteeism", fontsize=18, y=1)

plt.savefig('pairplot-hr-execessive.png', dpi=100)

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
fig.suptitle('Features Distribution in HR Abseenteism Data',fontsize=16)

# Feature1
sns.boxplot(ax=axes[0,0],x = df_preprocessed['Transportation Expense'], palette="magma")
axes[0,0].set_title('Transportation Expense')

# Feature2
sns.boxplot(ax=axes[0,1],x = df_preprocessed['Distance to Work'], palette="magma")
axes[0,1].set_title('Distance to Work')

# Feature3
sns.boxplot(ax=axes[0,2],x = df_preprocessed['Age'], palette="magma")
axes[0,2].set_title('Age')

# Feature1
sns.kdeplot(ax=axes[1,0],data = df_preprocessed['Transportation Expense'], palette="magma")
axes[1,0].set_title('Transportation Expense')

# Feature2
sns.kdeplot(ax=axes[1,1],data = df_preprocessed['Distance to Work'], palette="magma")
axes[1,1].set_title('Distance to Work')

# Feature3
sns.kdeplot(ax=axes[1,2],data = df_preprocessed['Age'], palette="magma")
axes[1,2].set_title('Age')

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='Transportation Expense', y='Distance to Work', data=df_preprocessed, hue='Excessive Absenteeism', ax=ax[0])
ax[0].set_title('Transportation Expense by Distance to Work', fontsize='14')

# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_preprocessed, x='Transportation Expense', y='Distance to Work', hue='Excessive Absenteeism', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Transportation Expense by Distance to Work', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
distance_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Distance to Work']
distance_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Distance to Work']
sns.histplot(data=df_preprocessed, x='Distance to Work', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Distance to Work', fontsize='14')

# Display the plots
plt.savefig('Transportation_Expense_by_Distance_to_Work.png')
plt.show()

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
transport_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Transportation Expense']
transport_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Transportation Expense']
sns.histplot(data=df_preprocessed, x='Transportation Expense', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[0])
ax[0].set_title('Transportation Expense', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
age_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Age']
age_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Age']
sns.histplot(data=df_preprocessed, x='Age', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[1])
ax[1].set_title('Age', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
distance_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Distance to Work']
distance_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Distance to Work']
sns.histplot(data=df_preprocessed, x='Distance to Work', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Distance to Work', fontsize='14')

# Display the plots
plt.savefig('Transportation_Expense_Age_Distance_to_Work.png')
plt.show()

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 4, figsize = (22,8))

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
reason_1_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['reason_1']
reason_1_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['reason_1']
sns.histplot(data=df_preprocessed, x='reason_1', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[0])
ax[0].set_title('reason_1', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
reason_2_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['reason_2']
reason_2_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['reason_2']
sns.histplot(data=df_preprocessed, x='reason_2', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[1])
ax[1].set_title('reason_2', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
reason_3_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['reason_3']
reason_3_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['reason_3']
sns.histplot(data=df_preprocessed, x='reason_3', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('reason_3', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
reason_4_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['reason_4']
reason_4_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['reason_4']
sns.histplot(data=df_preprocessed, x='reason_4', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[3])
ax[3].set_title('reason_4', fontsize='14')

# Display the plots
plt.savefig('reason_for_abseenteeism.png')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">Shown on the graph above from the highest absenteeism's  reasons are from reason  4,1,3 and 2 .
#     </p>

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 5, figsize = (22,8))

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
daily_work_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Daily Work Load Average']
daily_work_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Daily Work Load Average']
sns.histplot(data=df_preprocessed, x='Daily Work Load Average', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[0])
ax[0].set_title('Daily Work Load Average', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
body_mass_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Body Mass Index']
body_mass_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Body Mass Index']
sns.histplot(data=df_preprocessed, x='Body Mass Index', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[1])
ax[1].set_title('Body Mass Index', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
education_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Education']
education_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Education']
sns.histplot(data=df_preprocessed, x='Education', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Education', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
children_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Children']
children_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Children']
sns.histplot(data=df_preprocessed, x='Children', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[3])
ax[3].set_title('Children', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
pets_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Pets']
pets_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Pets']
sns.histplot(data=df_preprocessed, x='Pets', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[4])
ax[4].set_title('Pets', fontsize='14')

# Display the plots
plt.savefig('5_other_variables_abseenteeism.png')
plt.show()

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
month_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Month Value']
month_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Month Value']
sns.histplot(data=df_preprocessed, x='Month Value', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[0])
ax[0].set_title('Month Value', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
day_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Day of the week']
day_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Day of the week']
sns.histplot(data=df_preprocessed, x='Day of the week', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[1])
ax[1].set_title('Day of the week', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
year_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Year Value']
year_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Year Value']
sns.histplot(data=df_preprocessed, x='Year Value', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Year Value', fontsize='14')

# Display the plots
plt.savefig('YDM_Absenteeism.png')
plt.show()

# %%
# Set figure and axes
fig, ax = plt.subplots(1, 3, figsize = (22,8))

sns.scatterplot(x='Transportation Expense', y='Children', data=df_preprocessed, hue='Excessive Absenteeism', ax=ax[0])
ax[0].set_title('Transportation Expense by Children', fontsize='14')

# Create boxplot showing `average_monthly_hours` distributions for `number_project`, comparing employees who stayed versus those who left
sns.boxplot(data=df_preprocessed, x='Transportation Expense', y='Children', hue='Excessive Absenteeism', orient="h", ax=ax[1])
ax[1].invert_yaxis()
ax[1].set_title('Transportation Expense by Children', fontsize='14')

# Create histogram showing distribution of `number_project`, comparing employees who stayed versus those who left
distance_regular = df_preprocessed[df_preprocessed['Excessive Absenteeism']==0]['Children']
distance_excessive = df_preprocessed[df_preprocessed['Excessive Absenteeism']==1]['Children']
sns.histplot(data=df_preprocessed, x='Children', hue='Excessive Absenteeism', multiple='dodge', shrink=2, ax=ax[2])
ax[2].set_title('Children', fontsize='14')

# Display the plots
plt.savefig('Transportation_Expense_by_Children.png')
plt.show()

# %% [markdown]
# ## Define the Process
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#   <h3 style = "text-align:center">Table 1.6. SIPOC Analysis</h3>
#   <tr>
#     <th>Supplier (S)
#     <th colspan="2">Input (I)</th>
#     <th colspan="4">Process (P)</th>
#     <th colspan="2">Output (O)</th>
#     <th colspan="2">Customer (C)</th>
#   </tr>
#     <td>Employee
#     <br>Dept Head
#     <br>Employer</td>
#     <td colspan="2">Employee
#         <ul>
#             <li>Time & attendance policies/rules
#             <li>Time & attendance recording systems
#             <li>Employee communication/on boarding
#             <li>Line managers trained accountable
#             <li>Wellness policy/services
#         </ul></td>
#     <td style="background:LightSkyBlue;text-align:center">Employee absent without notice, noted in time & attendance system </td>
#     <td style="background:LightSkyBlue;text-align:center">Employee notifies or does not notify  employer</td>
#     <td style="background:LightSkyBlue;text-align:center">Employee return to work & investigation to establish facts</td>
#     <td style="background:LightSkyBlue">Reason accepted as valid & leave/time records adjusted</td>
#     <td style="background:LightSkyBlue">Reason accepted or not accepted as valid & leave/time records adjusted</td>
#     <td>
#     <ul>
#             <li>Update time/attendance & leave records
#             <li>Diciplinary process if appropriate
#             <li>Absenteeism tracking & trend analysis
#         </ul>
#     </td>
#     <td colspan="2" style="margin: auto; display:fill; word-wrap: break-word">
#         <ul>
#             <li>Dept Head
#             <li>HR
#             <li>Employer
#         </ul>
#     </td>
#  </table>
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px">Discussion should be conducted with the process' owner</p>
# </div>

# %% [markdown]
# ## Stakeholder Analysis
# <hr>
# <span style ="font-family:Verdana; font-size:16px; text-align:justify">In this project we will only be mapping the stakeholders that were mentioned in articles or sources with high impacts and major role to the Salifort Motors project.</span>
#
# <h3 style = "text-align:center">Table 1.7. Stakeholder Analysis</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <tr>
#     <th>Stakeholders</th>
#     <th>Role</th>
#     <th colspan="2">Involvement</th>
#     <th>Power or Influence (H/M/L)</th>
#     <th>Interest (H/M/L)</th>
#     <th colspan="2">Engagement</th>
#   </tr>
#   <tr>
#     <td>HR Director</td>
#     <td style = "text-align:left">
#       Project sponsor
#     </td>
#     <td colspan="2" style ="text-align:left">
#     Makes high-level decisions; serves as team resource
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td style ="text-align:center">
#       L
#     </td>
#     <td colspan="2" style ="text-align:left">
#       Communicate regularly, but not daily. Ask questions and give updates.
#     </td>
#   </tr>
#   <tr>
#     <td>Dept Head</td>
#     <td style = "text-align:left">
#       Project owner
#     </td>
#     <td colspan="2" style ="text-align:left">
#      <ul>
#          <li>Advisory role and providing valid information
#          <li>Implementation of preventive, diagnosis and treatment measures
#          <li>Allow re-export of surplus imported data or any required items to support project
#          <li>Formulation of the business requirements
#         <li>Formulation and implementation of equitable distribution of execution
#         </ul>
#     </td>
#     <td style ="text-align:center">
#       M
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td colspan="2" style ="text-align:left">
#       <ul>
#         <li>Informing, mentoring and coaching
#         <li>Monitoring the proper implementation of interventions
#         <li>Coordination in informing
#         <li>Official information reference in the Human Resource Management and
# control
#         <li>Training and consulting with other related organizations and institutions
#         </ul>
#     </td>
#   </tr>
#   <tr>
#     <td>HR Engagement and Retention</td>
#     <td style = "text-align:left">
#       Project leader
#     </td>
#     <td colspan="2" style ="text-align:left">
#      <ul>
#       <li>Project-rules making and planning
#      <li>Facilitate and synergy in inter-sectorial cooperation
#      <li>Identifying problems and providing solutions in the form of executive
#        approvals
#      </ul>
#     </td>
#     <td style ="text-align:center">
#       M
#     </td>
#     <td style ="text-align:center">
#       H
#     </td>
#     <td colspan="2" style ="text-align:left">
#        <ul>
#       <li>Synergy and strengthening of various capabilities across the team and organization,
#        directing and Mobilizing all capacities within the team.
#       <li>Lead project from the start to clossing.
#       </ul>
#     </td>
#   </tr>
#
#  </table>

# %% [markdown]
# #### Corellation to Ezxessive Absenteeism

# %%
df_preprocessed.corr()['Excessive Absenteeism'][:-1].sort_values(ascending=False).plot(kind='bar')

# %% [markdown]
# <h3 style = "text-align:center">Table 1.8. Project Charter</h3>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <tr>
#     <th colspan ="4" style="text-align:center">Project HR Employee Retention</th>
#   </tr>
#     <tr>
#     <th colspan ="4" style="text-align:center">31th May 2022</th>
#   </tr>
#   <tr>
#       <th colspan ="4" style="text-align:center">Document Status: <del>Draft</del> | In Review | <del>Approved</del></th>
#   </tr>
#   <tr>
#       <th colspan ="4" style="text-align:center">Executive Summary</th>
#   </tr>
#   <tr>
#       <td colspan ="4" style="text-align:center">develop a model that predicts employee excessive absenteeism profile.</td>
#   </tr>
#   <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Business Case</td>
#       <td colspan ="2">Problem/Opportunity Statement</td>
#   </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Based on the data company X, from 2015 to 2018 has employees who are absent more than 3 hours or disengaged employee around 46%. It is equal to 4030 absenteeism hours or unproductive hours across 2015 to 2018 (we can't quantify the loss as limited information). The work from home and also work back to office also can be a challenge.
# </td>
#       <td colspan ="2"><em>In this project</em> we establish a model to find ways to<b> predict employee absenteeism profile. </b>
# <br><br>The goal is to identify the people profile who are likely to have excessive absent and increase the hours to productive hours then absent hours,
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Goal Statement</td>
#       <td colspan ="2">Deliverables (Key Results)</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Primary metric:
#      <ul>
#          <li>Reduce absenteeism hours
#      </ul>
#      Secondary Metric:
#      <ul>
#          <li>Average monthly hours
#          <li>Evaluation
#      </ul>
#      </td>
#       <td colspan ="2">Primary Key Results:
#      <ul>
#          <li>Increase retention rate - reduce 50% of people absent more than 3 hours (the data provide the employee who engaged or disengaged).
#      </ul>
#      Secondary Key Results:
#      <ul>
#          <li>Number of project
#      </ul>
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Benefits, Cost, and Budget</td>
#       <td colspan ="2">Scope and Exclusion</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">Benefits:
#      <ul>
#          <li>Reducing 50% of employees (for below 50 employees) disengaged employee from unproductive hours $(No data provided) in avoidable costs.
#      </ul>
#      Costs:
#      <ul>
#          <li>Recruitment cost
#          <li>Training cost
#      </ul>
#      Budget Needed:
#            <span>TBD</span>
#      </td>
#       <td colspan ="2">In-Scope:
#      <ul>
#          <li>All department
#          <li>Full time
#      </ul>
#      Out-of-Scope:
#      <ul>
#          <li>Part Time or contract
#      </ul>
#      </td>
#   </tr>
#
#  <tr style ="background:LightSkyBlue;text-align:center">
#       <td colspan ="2">Project Team</td>
#       <td colspan ="2">Measuring Success</td>
#  </tr>
#  <tr style="text-align:left">
#       <td colspan ="2">
#      <ul>
#          <li>Sponsor: Laura, Director of HR
#          <li>Owner: Washington, Operations Manager
#          <li>Leader:Joko, Senior
#              HR Engagement and Retentioan
#          <li>Member: Denzel, Data Analysis Manager, jennifer, Senior Data Analyst, Wahyu Senior Data Analyst
#      </ul>
#      </td>
#
#   <td colspan ="2">Deliverables after solutions implementation:
#      <ul>
#          <li>Increase productivity hours
#      </ul>
#   </td>
#   </tr>
#   </table>

# %% [markdown]
# ### Select the inputs for Regression (Unscaled Inputs)
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px"><b>DataFrame.iloc[row indices,column indices]</b> select (slices) data by position when given rows and columns wanted pandas</p>
# </div>

# %%
df_with_targets = df_preprocessed #table

# %%
df_with_targets is df_preprocessed

# %%
df_with_targets.head()

# %%
df_with_targets.shape

# %%
df_with_targets.iloc[:,:15]# : all rows, and 0: 15 from 0 to 15 remove 0 will be the same

# %%
df_with_targets.iloc[:,:-1] # We can also similar code

# %%
unscaled_inputs = df_with_targets.iloc[:,:-1] # X

# %% [markdown]
# ### Standardize Data
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px"><b>We edited as to acquired the result</b> that is why we changed some code to comments.</p>
# </div>

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import StandardScaler

class CustomScaler(BaseEstimator, TransformerMixin):
    
    def __init__(self,columns):  # eliminate copy=True,with_mean=True,with_std=True
        self.scaler = StandardScaler() #eliminate copy, with_mean, with_std
        self.columns = columns
        self.mean_ = None
        self.var_ = None
        
    def fit(self, X, y=None): 
        self.scaler.fit(X[self.columns], y) #self.scaler.fit = (X[self.columns], y) - my mistake was typing =
        self.mean_ = np.mean(X[self.columns]) 
        self.var_ = np.var(X[self.columns]) 
        return self
    
    def transform(self, X, y=None, copy=None):
        init_col_order = X.columns
        X_scaled = pd.DataFrame(self.scaler.transform(X[self.columns]), columns = self.columns)
        X_not_scaled =  X.loc[:,~X.columns.isin(self.columns)]
        return pd.concat([X_not_scaled, X_scaled], axis=1)[init_col_order]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b style = "font-family: Arial; font-size: 16px">Above code is the renewed code</b>
#     <ol style = "text-align:justify; font-family: Verdana; font-size: 14px">
#         <li> This is the <b>Custom Scaler _init_</b> will not standardize all inputs but only the one we choose . This way the dummies will be untouched</li>
#         <li> Avoid the dummies  <b>Custom the scaled</b>.</li>
#     </ol>
# </div>

# %%
unscaled_inputs.columns.values

# %%
#columns_to_scale = ['Month Value','Day of the week', 'Year Value', 'Transportation Expense',
       #'Distance to Work', 'Age', 'Daily Work Load Average','Body Mass Index','Children', 'Pets']
    
columns_to_omit = ['reason_1', 'reason_2', 'reason_3', 'reason_4', 'Education']

# %%
# after creaing new columns to omit
columns_to_scale = [x for x in unscaled_inputs.columns.values if x not in columns_to_omit]

# %%
absenteeism_scaler = CustomScaler(columns_to_scale)

# %%
absenteeism_scaler.fit(unscaled_inputs) # This will calculate the mean and standard deviation. The standardize info will be in the absenteeism scaler

# %%
scaled_inputs = absenteeism_scaler.transform(unscaled_inputs) # we have to transform does the true scaling

# %%
scaled_inputs # all inputs data has been standardized

# %%
scaled_inputs.shape

# %% [markdown]
# ### Splitting the data into train and test and shuffle the data
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px"><b>The important not to Underfitting and Overfitting</b> Shuffle has to be randomize in the same way determine the random state</p>
# </div>

# %% [markdown]
# ### Import the relevant libraries

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Split

# %%
train_test_split(scaled_inputs, targets)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b style = "font-family: Arial; font-size: 16px">Outputs:</b>
#     <ol style = "text-align:justify; font-family: Verdana; font-size: 14px">
#         <li> Array 1 <b>a training dataset with inputs</b>.</li>
#         <li> Array 2 <b>a training dataset with targets</b>.</li>
#        <li> Array 3 <b>a test dataset with inputs</b>.</li>
#         <li> Array 4 <b>a test dataset with targets</b>.</li>
#     </ol>
#
# </div>

# %%
X_train,X_test, y_train, y_test = train_test_split(scaled_inputs, targets, train_size=0.8, random_state = 20) # we use 80% more training

# %%
print(X_train.shape,y_train.shape) #Vector length 525. 75% training default

# %%
print(X_test.shape,y_test.shape) #Vector length 175 25% test

# %% [markdown]
# ## Logistic Regression with sklearn
# ​
# ### Import the relevant libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
reg = LogisticRegression()

# %%
reg.fit(X_train,y_train)

# %%
reg.score(X_train,y_train)

# %% [markdown]
# ### Manually check the accuracy

# %%
model_outputs = reg.predict(X_train)
model_outputs

# %%
y_train

# %%
model_outputs == y_train

# %%
np.sum(model_outputs == y_train)

# %%
model_outputs.shape[0]

# %% [markdown]
# ### Finding the intercepts ($β_0$) - bias and the coefficient ($β_k$) - weight
#
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><p style = "font-family:Verdana; font-size:14px">Sklearn results (usually) are arrays, not dataframes.We have to transpose as nd.arrays are rows not colums.</p>
# </div>

# %%
reg.intercept_

# %%
reg.coef_

# %%
unscaled_inputs.columns.values

# %%
feature_name = unscaled_inputs.columns.values

# %%
summary_table = pd.DataFrame(columns=['Feature Name'], data = feature_name)

summary_table['Coefficient'] = np.transpose(reg.coef_)

summary_table

# %% [markdown]
# ### Interpreting the coefficient

# %%
summary_table['Odds_ratio'] = np.exp(summary_table.Coefficient)
summary_table

# %%
summary_table.sort_values('Odds_ratio', ascending = False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
summary_table_1 = summary_table
summary_table_1 = summary_table_1[(summary_table_1['Odds_ratio']>=1)&(summary_table_1['Coefficient']>=0)].sort_values('Odds_ratio', ascending = False)
summary_table_1

# %%
blankIndex=[''] * len(summary_table_1)
summary_table_1.index=blankIndex
summary_table_1

# %%
ticks=np.arange(8)
labels=summary_table_1['Feature Name']

# %%
plt.figure(figsize=(15,10))
summary_table_1.sort_values('Odds_ratio', ascending = False).plot(kind='bar')
plt.xticks(ticks,labels, rotation='vertical')
plt.savefig('log_reg1.png', dpi=100, bbox_inches = "tight")

# %%
sns.kdeplot(x='Odds_ratio', y='Coefficient', data=summary_table, logistic=True, ci=None)
plt.title('Odds ratio vs coefficient')

# %%
# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.tree import plot_tree

# For saving models
import pickle

# %%
y_pred = reg.predict(X_test)

# %%
# Create classification report for logistic regression model
target_names = ['Predicted engaged', 'Predicted disengaged - excessive absenteeism']
print(classification_report(y_test, y_pred, target_names=target_names))
print(confusion_matrix(y_test,y_pred))
print('\n')
print(accuracy_score(y_test,y_pred))

# %% [markdown]
# <img style="float:left" src="https://i.imgur.com/wpcEXQC.png" width="50"><div style = "font-family: Arial; font-size: 16px">
#     Execute</div>
#
# ## Conclussion
# <hr>
#
# <div class="alert alert-block alert-success" style="font-family:verdana; font-size:14px">The logistic regression model achieved precision of 73%, recall of 73%, f1-score of 73% (all weighted averages), and accuracy of 72.86%, on the test set.
# <br><br>
# Precision and recall scores are both useful to evaluate the correct predictive capability of a model because they balance the false positives and false negatives inherent in prediction.
# <br>
# The model shows a precision score of 73%, suggesting the model is not good at predicting true positives—meaning the the employee has excessive absenteeism while balancing false positives. The recall score of 73% also shows not good performance in predicting true negatives—where the excessive absenteeism will be charged off—while balancing false negatives.
# <br>
# To acquire more excessive absenteeism, the following feature importance with this model as follows:
# <br>
# <ol>
# <li> Reason 3, reason 1, reason 2 and reason 4 are the reasons which have importance to predict the model. Reason 3 and reason 1 have the strong feature importance.
# <li> Transportation expense between ~190 to 300 USD have the most employee with excessive absenteeism. We have to look to this further whether they can work from home,  as the distance with this range account of ~10 to 40 distance to work but not included as feature importance.
# <li> We can see the increase of children also decrease employee with excessive absenteeism. There are employees without children who are disengaged employees. We can also elaborate by separating to two groups without children (0) and with children (1).
# <li> Body mass index and month value.
# <br><br>
# Next Steps
# <br>
# It may be justified to still have some concern about data leakage and we only have small data of 700. We will continue to other models as the classification report still in 73%.
# </div>

# %% [markdown]
# ## Model 2: Decision Tree (1)

# %% [markdown]
# #### Encode the categorical variables

# %%
#Encode the categorical variables
df_1 = df_preprocessed

# %% [markdown]
# ### Split, Train and Test Data

# %%
# Isolate the outcome variable
y = df_1['Excessive Absenteeism'] #df_preprocessed['Excessive Absenteeism']=targets
# Select the features
X = df_1.drop('Excessive Absenteeism', axis=1) #df_with_targets.iloc[:,:-1] 

# Display the first few rows of `X`
X.head()

# %% [markdown]
# #### Training model

# %%
# Create test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=20)

# Create train & validate data
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.25, stratify=y_train, random_state=20)

# %% [markdown]
# #### Import the relevant libraries

# %%
# For displaying all of the columns in dataframes
pd.set_option('display.max_columns', None)

# For data modeling
from xgboost import XGBClassifier
from xgboost import XGBRegressor
from xgboost import plot_importance

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# For metrics and helpful functions
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.tree import plot_tree

# For saving models
import pickle

# %%
# Instantiate model
tree = DecisionTreeClassifier(random_state=20)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth':[3, 6, 9, None],
             'min_samples_leaf': [3, 5, 7],
             'min_samples_split': [3, 4, 5]
             }

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
tree1 = GridSearchCV(tree, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
tree1.fit(X_train, y_train) #1.83s

# %%
# Check best AUC score on CV
tree1.best_score_

# %%
def make_results(model_name:str, model_object, metric:str):
    '''
    Arguments:
        model_name (string): what you want the model to be called in the output table
        model_object: a fit GridSearchCV object
        metric (string): precision, recall, f1, accuracy, or auc
  
    Returns a pandas df with the F1, recall, precision, accuracy, and auc scores
    for the model with the best mean 'metric' score across all validation folds.  
    '''

    # Create dictionary that maps input metric to actual metric name in GridSearchCV
    metric_dict = {'auc': 'mean_test_roc_auc',
                 'precision': 'mean_test_precision',
                 'recall': 'mean_test_recall',
                 'f1': 'mean_test_f1',
                 'accuracy': 'mean_test_accuracy',
                 }

    # Get all the results from the CV and put them in a df
    cv_results = pd.DataFrame(model_object.cv_results_)

    # Isolate the row of the df with the max(metric) score
    best_estimator_results = cv_results.iloc[cv_results[metric_dict[metric]].idxmax(), :]

    # Extract Accuracy, precision, recall, and f1 score from that row
    auc = best_estimator_results.mean_test_roc_auc
    f1 = best_estimator_results.mean_test_f1
    recall = best_estimator_results.mean_test_recall
    precision = best_estimator_results.mean_test_precision
    accuracy = best_estimator_results.mean_test_accuracy
  
    # Create table of results
    table = pd.DataFrame()
    table = table.append({'Model': model_name,
                        'AUC': auc,
                        'Precision': precision,
                        'Recall': recall,
                        'F1': f1,
                        'Accuracy': accuracy,
                        },
                        ignore_index=True
                       )
  
    return table

# %%
# Get all CV scores
tree1_cv_results = make_results('decision tree cv', tree1, 'auc')
tree1_cv_results

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The classification report above shows that the decision tree results is lower than the logistic regression model achieved a precision of 69.86% compare to 73%, recall of 62.73% compare to 73%, f1-score of 65.86% to 73% (all weighted averages), and accuracy of 70.54% compare to 73%, and AUC 78.46% from decision tree to 73% of logistic regression. The AUC shows a good model.
#     </p>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <img style="float: left" src="https://i.postimg.cc/kXz8cFqC/005-Img-Yellow-Notes-Draft-1-20220819.png" width="60">
# <b style = "font-family: Arial; font-size: 16px">Note:</b><ol style = "font-family:Verdana; font-size:14px">
# Decision trees can be vulnerable to overfitting, and random forests avoid overfitting by incorporating multiple trees to make predictions. You could construct a random forest model next. The model may come up too good as we may required to conduct feature engineering. Moreover,
# we only apply standar scaller in logistic regression model not in the other models.
# </div>

# %%
def conf_matrix_plot(model, x_data, y_data):
    '''
    Accepts as argument model object, X data (test or validate), and y data (test or validate). 
    Returns a plot of confusion matrix for predictions on y data.
    ''' 
  
    model_pred = model.predict(x_data)
    cm = confusion_matrix(y_data, model_pred, labels=model.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=model.classes_)
  
    disp.plot(values_format='')
    plt.show()

# %%
# Generate confusion matrix
conf_matrix_plot(tree1, X_test, y_test)

# %%
# Plot the tree
plt.figure(figsize=(85,20))
plot_tree(tree1.best_estimator_, max_depth=6, fontsize=14, feature_names=X.columns, 
          class_names={0:'regular', 1:'exceed'}, filled=True)
plt.savefig('tree1.png', dpi=400, bbox_inches = "tight")
plt.show()

# %%
#tree1_importances = pd.DataFrame(tree1.best_estimator_.feature_importances_, columns=X.columns)
tree1_importances = pd.DataFrame(tree1.best_estimator_.feature_importances_, columns=['gini_importance'], index=X.columns)
tree1_importances = tree1_importances.sort_values(by='gini_importance', ascending=False)

# Only extract the features with importances > 0
tree1_importances = tree1_importances[tree1_importances['gini_importance'] != 0]
tree1_importances

# %%
sns.barplot(data=tree1_importances, x="gini_importance", y=tree1_importances.index, orient='h')
plt.title("Decision Tree: Feature Importances forExcessive Absenteeism", fontsize=12)
plt.ylabel("Feature")
plt.xlabel("Importance")
plt.savefig('tree1-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px"> Compare to the logistic regression, the decision tree strong features from the stronger is the satisfaction level, last evaluation, number project, tenure, average monthly hours, salary and technical department. This result is very different compare the odds ratio of the logistic regression.
#     </p>

# %% [markdown]
# ## Model 3: Random Forrest (1)

# %%
# Instantiate model
rf = RandomForestClassifier(random_state=20)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [2,4, None], 
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [3,5,7],
             'min_samples_split': [3,4,6],
             'n_estimators': [300, 500],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf1 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf1.fit(X_tr, y_tr) # --> Wall time: ~5:4s

# %%
# Define a path to the folder where you want to save the model
path = '/kaggle/working/'

# %%
def write_pickle(path, model_object, save_as:str):
    '''
    In: 
        path:         path of folder where you want to save the pickle
        model_object: a model you want to pickle
        save_as:      filename for how you want to save the model

    Out: A call to pickle the model in the folder indicated
    '''    

    with open(path + save_as + '.pickle', 'wb') as to_write:
        pickle.dump(model_object, to_write)

# %%
def read_pickle(path, saved_model_name:str):
    '''
    In: 
        path:             path to folder where you want to read from
        saved_model_name: filename of pickled model you want to read in

    Out: 
        model: the pickled model 
    '''
    with open(path + saved_model_name + '.pickle', 'rb') as to_read:
        model = pickle.load(to_read)

    return model

# %%
# Write pickle
write_pickle(path, rf1, 'hr_rf1')

# %%
# Read pickle
rf1 = read_pickle(path, 'hr_rf1')

# %%
# Check best AUC score on CV
rf1.best_score_

# %%
# Get all CV scores
rf1_cv_results = make_results('random forest cv', rf1, 'auc')
print(tree1_cv_results)
print(rf1_cv_results)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The AUC from the random forest is 75.81%, precision and accuracy which lower than of decision tree.
#     </p>

# %%
def get_scores(model_name:str, model, X_test_data, y_test_data):
    '''
    Generate a table of test scores.

    In: 
        model_name (string):  How you want your model to be named in the output table
        model:                A fit GridSearchCV object
        X_test_data:          numpy array of X_test data
        y_test_data:          numpy array of y_test data

    Out: pandas df of precision, recall, f1, accuracy, and AUC scores for your model
    '''

    preds = model.best_estimator_.predict(X_test_data)

    auc = round(roc_auc_score(y_test_data, preds), 3)
    accuracy = round(accuracy_score(y_test_data, preds), 3)
    precision = round(precision_score(y_test_data, preds), 3)
    recall = round(recall_score(y_test_data, preds), 3)
    f1 = round(f1_score(y_test_data, preds), 3)

    table = pd.DataFrame({'model': [model_name],
                        'AUC': [auc],
                        'precision': [precision], 
                        'recall': [recall],
                        'f1': [f1],
                        'accuracy': [accuracy]
                        })
  
    return table

# %%
# Get the results on validation set for both models
tree1_val_results = get_scores('decision tree1 val', tree1, X_val, y_val)
rf1_val_results = get_scores('random forest1 val', rf1, X_val, y_val)

# Concatenate validation scores into table
all_val_results1 = [tree1_val_results, rf1_val_results]
all_val_results1 = pd.concat(all_val_results1).sort_values(by='AUC', ascending=False)
all_val_results1

# %%
# Get predictions on test data
rf1_test_scores = get_scores('random forest1 test', rf1, X_test, y_test)
rf1_test_scores

# %%
# Generate array of values for confusion matrix
preds = rf1.best_estimator_.predict(X_test)
cm = confusion_matrix(y_test, preds, labels=rf1.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=rf1.classes_)
disp.plot()

# %%
# Get feature importances
feat_impt = rf1.best_estimator_.feature_importances_

# Get indices of top 10 features
ind = np.argpartition(rf1.best_estimator_.feature_importances_, -10)[-10:]

# Get column labels of top 10 features 
feat = X.columns[ind]

# Filter `feat_impt` to consist of top 10 feature importances
feat_impt = feat_impt[ind]

y_df = pd.DataFrame({"Feature":feat,"Importance":feat_impt})
y_sort_df = y_df.sort_values("Importance")
fig = plt.figure()
ax1 = fig.add_subplot(111)

y_sort_df.plot(kind='barh',ax=ax1,x="Feature",y="Importance")

ax1.set_title("Random Forest: Feature Importances for Excessive Absenteeism", fontsize=12)
ax1.set_ylabel("Feature")
ax1.set_xlabel("Importance")
plt.savefig('rf1-importance.png', dpi=400, bbox_inches = "tight")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The feature importance of Random Forest, Decision Tree and Logistic Regression show different results.
# </p>

# %% [markdown]
# ## Model 4: XGBoost (1)

# %%
# 1. Instantiate the XGBoost classifier
xgb = XGBClassifier(objective='binary:logistic', random_state=20)  

# 2. Create a dictionary of hyperparameters to tune
cv_params = {'max_depth': [4,8,12], 
             'min_child_weight': [3, 5],
             'learning_rate': [0.01, 0.1],
             'n_estimators': [300, 500]
             }   

# 3. Define a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1'}

# 4. Instantiate the GridSearchCV object
xgb_cv1 = GridSearchCV(xgb, cv_params, scoring=scoring, cv=4, refit='f1')

# %%
# %%time
# # avg. 1 min 47s
xgb_cv1.fit(X_train, y_train)

# %%
write_pickle(path, xgb_cv1, 'hr_xgb_cv1')

# %%
# Examine best score
xgb_cv1.best_score_

# %%
# Get all CV scores Error
#xgb_cv1_results = make_results('xgboost cv', xgb_cv1, 'auc')
#print(tree1_cv_results)
#print(rf1_cv_results)
#print(xgb_cv1_results)

# %%
# Examine best parameters
xgb_cv1.best_params_

# %%
# Get scores on test data
preds = xgb_cv1.best_estimator_.predict(X_test)

# %%
# Get scores on test data
xgb_cv1_test_scores = get_scores('XGBoost 1: test',xgb_cv1, X_test, y_test)
xgb_cv1_test_scores

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The AUC from the random forest is 79.4%, precision 75.4%, recall 81.2%, f1 is 78.2% and accuracy of 79.3%  which higher than of decision tree.
#     </p>

# %%
# Generate array of values for confusion matrix
cm = confusion_matrix(y_test, preds, labels=xgb_cv1.classes_)

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=xgb_cv1.classes_)
disp.plot();

# %%
plot_importance(xgb_cv1.best_estimator_, max_num_features=10);
plt.savefig('xgboost1-importance.png', dpi=400, bbox_inches = "tight")

# %% [markdown]
# <div class="alert alert-block alert-info">
# <img style="float: left" src="https://i.imgur.com/HVpiyd6.png[/img" width="60">
# <b style = "font-family: Arial; font-size: 16px">Results:</b><p style = "font-family:Verdana; font-size:14px">The feature importance of XGBoost is different from other models.
# </p>

# %% [markdown]
# ## Add : KMeans (1) - Cluster
#
# #### Scaled data

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
# Scale the data
X_scaled = StandardScaler().fit_transform(X)

# %%
# Fit K-means and evaluate inertia for different values of k.

### YOUR CODE HERE ###

num_clusters = [i for i in range(2, 30)]

def kmeans_inertia(num_clusters, x_vals):
    """
    Accepts as arguments list of ints and data array. 
    Fits a KMeans model where k = each value in the list of ints. 
    Returns each k-value's inertia appended to a list.
    """
    inertia = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=0)
        kms.fit(x_vals)
        inertia.append(kms.inertia_)

    return inertia

# %%
# Return a list of inertia for k=2 to 30.

### YOUR CODE HERE ###

inertia = kmeans_inertia(num_clusters, X_scaled)
inertia

# %% [markdown]
# #### Elbow Plot

# %%
# Create an elbow plot
plt.figure(figsize=(12,6))
plot = sns.lineplot(x=num_clusters, y=inertia, marker = 'o')
plot.set_xlabel("Number of clusters")
plot.set_ylabel("Inertia")

# %% [markdown]
# #### Evaluate silhouette score
#
# <div style = "font-family: Arial; font-size: 16px">
# Unlike inertia, silhouette score doesn't have its own attribute that can be called on the model object. To get a silhouette score, we have to use the `silhouette_score()` function that we imported from `sklearn.metrics`. You must pass to it two required parameters: your training data and their assigned cluster labels. Let's see what this looks like for the `kmeans~8` model we created earlier.</div>

# %%
# Instantiate model
kmeans18 = KMeans(n_clusters=18, random_state=20)
kmeans18.fit(X_scaled)

# %%
# Get silhouette score for kmeans3 model
kmeans18_sil_score = silhouette_score(X_scaled, kmeans18.labels_)
kmeans18_sil_score

# %%
def kmeans_sil(num_clusters, x_vals):
    '''
    Fits a KMeans model for different values of k.
    Calculates a silhouette score for each k value

    Args:
        num_clusters: (list of ints)  - The different k values to try
        x_vals:       (array)         - The training data

    Returns: 
        sil_score:    (list)          - A list of silhouette scores, one for each \
                                      value of k
    '''
  
    sil_score = []
    for num in num_clusters:
        kms = KMeans(n_clusters=num, random_state=42)
        kms.fit(x_vals)
        sil_score.append(silhouette_score(x_vals, kms.labels_))
    
    return sil_score

# %%
# Calculate silhouette scores for k=2-30
sil_score = kmeans_sil(num_clusters, X_scaled)
sil_score

# %%
# Create a line plot of silhouette scores 
plot = sns.lineplot(x=num_clusters, y=sil_score, marker = 'o')
plot.set_xlabel("# of clusters")
plot.set_ylabel("Silhouette Score")

# %% [markdown]
# <hr>
# <table style="color:black;
#            display:fill;
#            border-colapse: colapse;
#            width: 100%;
#            border: 1px solid black;
#            border-collapse: collapse;
#            border-style: solid;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#
#   <h3 style = "text-align:center">Table 2. Machine Learning Model Feature Importance </h3>
#   <tr>
#     <th>XG Boost (1)</th>
#     <th>Decision Tree (1)</th>
#     <th>Random Forest (1)</th>
#   </tr>
#   <tr style = "text-align:center">
#       <td><img style= "margin:auto" src="https://i.imgur.com/fRCagnV.png" width = "600"></td>
#       <td><img style= "margin:auto" src="https://i.imgur.com/r5NT76p.png" width = "600"></td>
#       <td><img style= "margin:auto" src="https://i.imgur.com/kBpwsEl.png" width = "600"></td>
#   </tr>
#   </table>

# %% [markdown]
# ## Conclussion
# <hr>
#
# <div class="alert alert-block alert-success" style="font-family:verdana; font-size:14px">
#
# Logistic Regression
# <br><br>
# The logistic regression model achieved precision of 73%, recall of 73%, f1-score of 73% (all weighted averages), and accuracy of 72.86%, on the test set.
# <br><br>
# Tree-based Machine Learning
# <br><br>
# We only still in the level 01 (baseline) and has not done feature engineering, the xgboost model achieved AUC of 79.4%, precision of 75.4%, recall of 81.2%, f1-score of 78.2%, and accuracy of 19.3%, on the test set. The random forest and decision tree model slightly underperformed the decision tree model
# <br>
# The models and the feature importances extracted from the models baseline shows that employees at the company are drive by the trasport expense.
# <br><br>
# To preliminary reduce absenteeism, the following recommendations could be presented to the stakeholders:
# <br><br>
# <ol>
# <li> Transportation expense between ~190 to 300 USD have the most employee with excessive absenteeism. We have to look to this further whether they can work from home,  as the distance with this range account of ~10 to 40 distance to work but not included as feature importance.
# <li>  We can see that there are employees who are overworked increase in ~240-300 hours
# <li> We can see the increase of children also decrease employee with excessive absenteeism. There are employees without children who are disengaged employees. We can also elaborate by separating to two groups without children (0) and with children (1).
# <li>Ensure that employee has understood the overtime policy, check and if the employee has been given information accordingly.  Consider that employee can exchange their overtime with more paid leave of holiday or vacation.
# <li>Ensure that employee has understood the absenteeism policy, check and if the employee has been given information accordingly.
# <li>Important to have team or department as well in company-wide discussion regarding the work culture.
# <li> Body mass index and month value, provide gym or healthy programs.
# <br><br>
# Next Steps
# <br>
# It may be justified to still have some concern about data leakage and we only have small data of 700. Feture engineering is required to confirm the results further.
# </div>
